# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max()-x.min() ))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group', ['A','B','C','D'])

# %%
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, assigned_group, age_bucket]

# %% [markdown]
# ### Train Test Split

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
#labels

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size=0.3, random_state=101)

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x139e84630>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2898: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 296.947
# INFO:tensorflow:loss = 6.4297857, step = 101 (0.338 sec)
# INFO:tensorflow:global_step/sec: 463.006
# INFO:tensorflow:loss = 7.9575887, step = 201 (0.216 sec)
# INFO:tensorflow:global_step/sec: 523.664
# INFO:tensorflow:loss = 7.4615316, step = 301 (0.192 sec)
# INFO:tensorflow:global_step/sec: 497.382
# INFO:tensorflow:loss = 4.1004734, step = 401 (0.200 sec)
# INFO:tensorflow:global_step/sec: 539.118
# INFO:tensorflow:loss = 6.8494744, step = 501 (0.185 sec)
# INFO:tensorflow:global_step/sec: 469.4
# INFO:tensorflow:loss = 4.380101, step = 601 (0.216 sec)
# INFO:tensorflow:global_step/sec: 462.338
# INFO:tensorflow:loss = 5.1841173, step = 701 (0.217 sec)
# INFO:tensorflow:global_step/sec: 496.219
# INFO:tensorflow:loss = 4.790333, step = 801 (0.200 sec)
# INFO:tensorflow:global_step/sec: 566.756
# INFO:tensorflow:loss = 7.424851, step = 901 (0.175 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.7141104.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/ops/metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-22T08:47:19Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-06-22-08:47:20
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74025977, accuracy_baseline = 0.64935064, auc = 0.8029218, auc_precision_recall = 0.6486318, average_loss = 0.5256769, global_step = 1000, label/mean = 0.35064936, loss = 5.0596404, precision = 0.6666667, prediction/mean = 0.35320207, recall = 0.5185185
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.74025977,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8029218,
#  'auc_precision_recall': 0.6486318,
#  'average_loss': 0.5256769,
#  'label/mean': 0.35064936,
#  'loss': 5.0596404,
#  'precision': 0.6666667,
#  'prediction/mean': 0.35320207,
#  'recall': 0.5185185,
#  'global_step': 1000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmp2ihl70xy/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'logits': array([0.01549315], dtype=float32),
#   'logistic': array([0.5038732], dtype=float32),
#   'probabilities': array([0.4961268, 0.5038732], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.47227168], dtype=float32),
#   'logistic': array([0.61592126], dtype=float32),
#   'probabilities': array([0.38407874, 0.6159213 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6757918], dtype=float32),
#   'logistic': array([0.33720118], dtype=float32),
#   'probabilities': array([0.6627988 , 0.33720118], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.71320724], dtype=float32),
#   'logistic': array([0.32889056], dtype=float32),
#   'probabilities': array([0.6711095 , 0.32889056], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7633927], dtype=float32),
#   'logistic': array([0.14636594], dtype=float32),
#   'probabilities': array([0.85363406, 0.14636594], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7467538], dtype=float32),
#   'logistic': array([0.67847097], dtype=float32),
#   'probabilities': array([0.32152903, 0.67847097], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.35005462], dtype=float32),
#   'logistic': array([0.5866308], dtype=float32),
#   'probabilities': array([0.41336915, 0.5866308 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.78601325], dtype=float32),
#   'logistic': array([0.31302536], dtype=float32),
#   'probabilities': array([0.6869747 , 0.31302536], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2083027], dtype=float32),
#   'logistic': array([0.23000152], dtype=float32),
#   'probabilities': array([0.76999855, 0.23000151], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2438397], dtype=float32),
#   'logistic': array([0.22376834], dtype=float32),
#   'probabilities': array([0.77623165, 0.22376832], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8475509], dtype=float32),
#   'logistic': array([0.13616073], dtype=float32),
#   'probabilities': array([0.8638393, 0.1361607], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6647115], dtype=float32),
#   'logistic': array([0.15913057], dtype=float32),
#   'probabilities': array([0.8408695 , 0.15913056], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0024596], dtype=float32),
#   'logistic': array([0.26845813], dtype=float32),
#   'probabilities': array([0.73154193, 0.2684581 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.16516125], dtype=float32),
#   'logistic': array([0.5411967], dtype=float32),
#   'probabilities': array([0.4588033, 0.5411967], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5408149], dtype=float32),
#   'logistic': array([0.17641684], dtype=float32),
#   'probabilities': array([0.8235832 , 0.17641686], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7653054], dtype=float32),
#   'logistic': array([0.31749552], dtype=float32),
#   'probabilities': array([0.6825045 , 0.31749552], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6249235], dtype=float32),
#   'logistic': array([0.3486625], dtype=float32),
#   'probabilities': array([0.6513375, 0.3486625], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8946501], dtype=float32),
#   'logistic': array([0.13071513], dtype=float32),
#   'probabilities': array([0.8692848 , 0.13071518], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6931442], dtype=float32),
#   'logistic': array([0.333334], dtype=float32),
#   'probabilities': array([0.66666603, 0.333334  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7546979], dtype=float32),
#   'logistic': array([0.14745563], dtype=float32),
#   'probabilities': array([0.85254437, 0.14745563], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.309726], dtype=float32),
#   'logistic': array([0.2125327], dtype=float32),
#   'probabilities': array([0.7874673, 0.2125327], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9060068], dtype=float32),
#   'logistic': array([0.28781766], dtype=float32),
#   'probabilities': array([0.71218234, 0.2878177 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.47479737], dtype=float32),
#   'logistic': array([0.6165186], dtype=float32),
#   'probabilities': array([0.3834814, 0.6165186], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2996209], dtype=float32),
#   'logistic': array([0.21422884], dtype=float32),
#   'probabilities': array([0.7857712 , 0.21422884], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5964813], dtype=float32),
#   'logistic': array([0.16847396], dtype=float32),
#   'probabilities': array([0.831526  , 0.16847397], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.075558], dtype=float32),
#   'logistic': array([0.74565244], dtype=float32),
#   'probabilities': array([0.25434753, 0.74565244], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5502203], dtype=float32),
#   'logistic': array([0.17505443], dtype=float32),
#   'probabilities': array([0.8249455 , 0.17505446], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.77711403], dtype=float32),
#   'logistic': array([0.31494224], dtype=float32),
#   'probabilities': array([0.6850578, 0.3149422], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1205487], dtype=float32),
#   'logistic': array([0.10711557], dtype=float32),
#   'probabilities': array([0.89288443, 0.10711558], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.22200489], dtype=float32),
#   'logistic': array([0.55527437], dtype=float32),
#   'probabilities': array([0.44472557, 0.55527437], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.6657343], dtype=float32),
#   'logistic': array([0.9349742], dtype=float32),
#   'probabilities': array([0.06502583, 0.9349742 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.4008429], dtype=float32),
#   'logistic': array([0.40110984], dtype=float32),
#   'probabilities': array([0.5988902 , 0.40110987], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7459245], dtype=float32),
#   'logistic': array([0.32171002], dtype=float32),
#   'probabilities': array([0.67829, 0.32171], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.07644629], dtype=float32),
#   'logistic': array([0.5191023], dtype=float32),
#   'probabilities': array([0.48089775, 0.5191023 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2155317], dtype=float32),
#   'logistic': array([0.22872373], dtype=float32),
#   'probabilities': array([0.77127624, 0.22872373], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.64424485], dtype=float32),
#   'logistic': array([0.34428763], dtype=float32),
#   'probabilities': array([0.65571237, 0.3442876 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.1172384], dtype=float32),
#   'logistic': array([0.47072393], dtype=float32),
#   'probabilities': array([0.5292761 , 0.47072393], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3567611], dtype=float32),
#   'logistic': array([0.5882562], dtype=float32),
#   'probabilities': array([0.41174382, 0.5882561 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.008276], dtype=float32),
#   'logistic': array([0.73268265], dtype=float32),
#   'probabilities': array([0.26731738, 0.73268265], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6942042], dtype=float32),
#   'logistic': array([0.33309847], dtype=float32),
#   'probabilities': array([0.6669015 , 0.33309847], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5228603], dtype=float32),
#   'logistic': array([0.1790407], dtype=float32),
#   'probabilities': array([0.82095927, 0.1790407 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.1415788], dtype=float32),
#   'logistic': array([0.53533566], dtype=float32),
#   'probabilities': array([0.46466428, 0.53533566], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7559471], dtype=float32),
#   'logistic': array([0.14729866], dtype=float32),
#   'probabilities': array([0.85270137, 0.14729866], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.03939927], dtype=float32),
#   'logistic': array([0.50984854], dtype=float32),
#   'probabilities': array([0.49015144, 0.50984854], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8661671], dtype=float32),
#   'logistic': array([0.13398582], dtype=float32),
#   'probabilities': array([0.8660142 , 0.13398585], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9476926], dtype=float32),
#   'logistic': array([0.12480521], dtype=float32),
#   'probabilities': array([0.87519485, 0.12480517], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.26860034], dtype=float32),
#   'logistic': array([0.5667493], dtype=float32),
#   'probabilities': array([0.43325076, 0.5667493 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4971216], dtype=float32),
#   'logistic': array([0.18285525], dtype=float32),
#   'probabilities': array([0.81714475, 0.18285522], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4956479], dtype=float32),
#   'logistic': array([0.18307552], dtype=float32),
#   'probabilities': array([0.8169245 , 0.18307553], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.861665], dtype=float32),
#   'logistic': array([0.1345091], dtype=float32),
#   'probabilities': array([0.8654909, 0.1345091], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5341109], dtype=float32),
#   'logistic': array([0.17739302], dtype=float32),
#   'probabilities': array([0.822607, 0.177393], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1138369], dtype=float32),
#   'logistic': array([0.24715629], dtype=float32),
#   'probabilities': array([0.75284374, 0.24715626], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.052203], dtype=float32),
#   'logistic': array([0.25880226], dtype=float32),
#   'probabilities': array([0.7411977 , 0.25880226], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5786204], dtype=float32),
#   'logistic': array([0.35925013], dtype=float32),
#   'probabilities': array([0.6407499 , 0.35925007], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9942789], dtype=float32),
#   'logistic': array([0.11980489], dtype=float32),
#   'probabilities': array([0.88019514, 0.11980492], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2279437], dtype=float32),
#   'logistic': array([0.22654155], dtype=float32),
#   'probabilities': array([0.7734585 , 0.22654153], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3024287], dtype=float32),
#   'logistic': array([0.21375653], dtype=float32),
#   'probabilities': array([0.78624344, 0.21375656], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3131143], dtype=float32),
#   'logistic': array([0.21196619], dtype=float32),
#   'probabilities': array([0.7880338 , 0.21196617], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.2513771], dtype=float32),
#   'logistic': array([0.4374846], dtype=float32),
#   'probabilities': array([0.56251544, 0.4374846 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6275314], dtype=float32),
#   'logistic': array([0.1641688], dtype=float32),
#   'probabilities': array([0.83583117, 0.16416882], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2366781], dtype=float32),
#   'logistic': array([0.22501475], dtype=float32),
#   'probabilities': array([0.77498525, 0.22501475], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4512943], dtype=float32),
#   'logistic': array([0.6109469], dtype=float32),
#   'probabilities': array([0.38905308, 0.61094695], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.38362384], dtype=float32),
#   'logistic': array([0.5947468], dtype=float32),
#   'probabilities': array([0.40525314, 0.5947468 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.09184587], dtype=float32),
#   'logistic': array([0.47705466], dtype=float32),
#   'probabilities': array([0.52294534, 0.47705466], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.55674803], dtype=float32),
#   'logistic': array([0.36430025], dtype=float32),
#   'probabilities': array([0.6356998 , 0.36430025], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.19768625], dtype=float32),
#   'logistic': array([0.45073876], dtype=float32),
#   'probabilities': array([0.5492613, 0.4507388], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4965882], dtype=float32),
#   'logistic': array([0.18293491], dtype=float32),
#   'probabilities': array([0.8170651 , 0.18293494], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5086361], dtype=float32),
#   'logistic': array([0.18114099], dtype=float32),
#   'probabilities': array([0.81885904, 0.18114102], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7371335], dtype=float32),
#   'logistic': array([0.1496774], dtype=float32),
#   'probabilities': array([0.85032266, 0.14967741], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9777344], dtype=float32),
#   'logistic': array([0.12156056], dtype=float32),
#   'probabilities': array([0.8784394 , 0.12156054], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.41963542], dtype=float32),
#   'logistic': array([0.603396], dtype=float32),
#   'probabilities': array([0.396604, 0.603396], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2699597], dtype=float32),
#   'logistic': array([0.21926418], dtype=float32),
#   'probabilities': array([0.78073585, 0.21926415], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.28380865], dtype=float32),
#   'logistic': array([0.4295203], dtype=float32),
#   'probabilities': array([0.5704797 , 0.42952028], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.25701928], dtype=float32),
#   'logistic': array([0.56390345], dtype=float32),
#   'probabilities': array([0.43609658, 0.5639034 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.8633775], dtype=float32),
#   'logistic': array([0.2966342], dtype=float32),
#   'probabilities': array([0.7033658 , 0.29663417], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.45402813], dtype=float32),
#   'logistic': array([0.6115965], dtype=float32),
#   'probabilities': array([0.38840345, 0.6115965 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8873205], dtype=float32),
#   'logistic': array([0.13155031], dtype=float32),
#   'probabilities': array([0.86844975, 0.13155028], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.43238842], dtype=float32),
#   'logistic': array([0.6064439], dtype=float32),
#   'probabilities': array([0.39355615, 0.6064439 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9194995], dtype=float32),
#   'logistic': array([0.1279174], dtype=float32),
#   'probabilities': array([0.8720826 , 0.12791738], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.19378221], dtype=float32),
#   'logistic': array([0.54829454], dtype=float32),
#   'probabilities': array([0.4517055 , 0.54829454], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.7706292], dtype=float32),
#   'logistic': array([0.316343], dtype=float32),
#   'probabilities': array([0.683657, 0.316343], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7078967], dtype=float32),
#   'logistic': array([0.15343669], dtype=float32),
#   'probabilities': array([0.8465633 , 0.15343672], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.11226213], dtype=float32),
#   'logistic': array([0.5280361], dtype=float32),
#   'probabilities': array([0.4719639, 0.5280361], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.3346771], dtype=float32),
#   'logistic': array([0.58289695], dtype=float32),
#   'probabilities': array([0.41710305, 0.58289695], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.0677861], dtype=float32),
#   'logistic': array([0.51694006], dtype=float32),
#   'probabilities': array([0.4830599, 0.51694  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5965565], dtype=float32),
#   'logistic': array([0.16846341], dtype=float32),
#   'probabilities': array([0.83153653, 0.16846342], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5980655], dtype=float32),
#   'logistic': array([0.3547864], dtype=float32),
#   'probabilities': array([0.6452136 , 0.35478643], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7231505], dtype=float32),
#   'logistic': array([0.1514658], dtype=float32),
#   'probabilities': array([0.84853417, 0.1514658 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.66001], dtype=float32),
#   'logistic': array([0.65926266], dtype=float32),
#   'probabilities': array([0.34073737, 0.65926266], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.19228], dtype=float32),
#   'logistic': array([0.7671486], dtype=float32),
#   'probabilities': array([0.23285142, 0.7671486 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.40280366], dtype=float32),
#   'logistic': array([0.59936106], dtype=float32),
#   'probabilities': array([0.4006389 , 0.59936106], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3002226], dtype=float32),
#   'logistic': array([0.21412754], dtype=float32),
#   'probabilities': array([0.7858724 , 0.21412754], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.16138864], dtype=float32),
#   'logistic': array([0.4597402], dtype=float32),
#   'probabilities': array([0.5402598, 0.4597402], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.49948263], dtype=float32),
#   'logistic': array([0.37766227], dtype=float32),
#   'probabilities': array([0.62233776, 0.37766227], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.40815234], dtype=float32),
#   'logistic': array([0.39935526], dtype=float32),
#   'probabilities': array([0.6006447, 0.3993552], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.64289695], dtype=float32),
#   'logistic': array([0.34459198], dtype=float32),
#   'probabilities': array([0.655408  , 0.34459198], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.34756172], dtype=float32),
#   'logistic': array([0.41397384], dtype=float32),
#   'probabilities': array([0.5860262, 0.4139738], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7616198], dtype=float32),
#   'logistic': array([0.14658758], dtype=float32),
#   'probabilities': array([0.85341245, 0.1465876 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.11681056], dtype=float32),
#   'logistic': array([0.52916944], dtype=float32),
#   'probabilities': array([0.4708305 , 0.52916944], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.05678165], dtype=float32),
#   'logistic': array([0.51419157], dtype=float32),
#   'probabilities': array([0.48580834, 0.51419157], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1447794], dtype=float32),
#   'logistic': array([0.24144393], dtype=float32),
#   'probabilities': array([0.7585561 , 0.24144395], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6325693], dtype=float32),
#   'logistic': array([0.1634787], dtype=float32),
#   'probabilities': array([0.8365213, 0.1634787], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5758417], dtype=float32),
#   'logistic': array([0.1713852], dtype=float32),
#   'probabilities': array([0.82861483, 0.17138521], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.966992], dtype=float32),
#   'logistic': array([0.27548045], dtype=float32),
#   'probabilities': array([0.7245195 , 0.27548045], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.54513687], dtype=float32),
#   'logistic': array([0.36699343], dtype=float32),
#   'probabilities': array([0.6330066 , 0.36699346], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9064014], dtype=float32),
#   'logistic': array([0.12938565], dtype=float32),
#   'probabilities': array([0.87061435, 0.12938568], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.71700513], dtype=float32),
#   'logistic': array([0.32805282], dtype=float32),
#   'probabilities': array([0.6719472 , 0.32805282], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3077861], dtype=float32),
#   'logistic': array([0.21285757], dtype=float32),
#   'probabilities': array([0.78714246, 0.21285754], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.216521], dtype=float32),
#   'logistic': array([0.09827668], dtype=float32),
#   'probabilities': array([0.9017234 , 0.09827668], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9083436], dtype=float32),
#   'logistic': array([0.12916707], dtype=float32),
#   'probabilities': array([0.8708329 , 0.12916705], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.93759894], dtype=float32),
#   'logistic': array([0.7186144], dtype=float32),
#   'probabilities': array([0.2813856, 0.7186144], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5515776], dtype=float32),
#   'logistic': array([0.17485854], dtype=float32),
#   'probabilities': array([0.8251415 , 0.17485854], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.944623], dtype=float32),
#   'logistic': array([0.12514088], dtype=float32),
#   'probabilities': array([0.87485915, 0.12514085], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7380213], dtype=float32),
#   'logistic': array([0.14956442], dtype=float32),
#   'probabilities': array([0.85043555, 0.14956446], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.13940084], dtype=float32),
#   'logistic': array([0.46520612], dtype=float32),
#   'probabilities': array([0.5347939 , 0.46520612], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.23472184], dtype=float32),
#   'logistic': array([0.44158748], dtype=float32),
#   'probabilities': array([0.5584125 , 0.44158745], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1655661], dtype=float32),
#   'logistic': array([0.2376574], dtype=float32),
#   'probabilities': array([0.76234263, 0.23765738], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.2597258], dtype=float32),
#   'logistic': array([0.43543112], dtype=float32),
#   'probabilities': array([0.5645689, 0.4354311], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5467156], dtype=float32),
#   'logistic': array([0.17556114], dtype=float32),
#   'probabilities': array([0.82443887, 0.17556114], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.175725], dtype=float32),
#   'logistic': array([0.23582172], dtype=float32),
#   'probabilities': array([0.7641783 , 0.23582174], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.02722049], dtype=float32),
#   'logistic': array([0.5068047], dtype=float32),
#   'probabilities': array([0.49319533, 0.5068047 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.16142541], dtype=float32),
#   'logistic': array([0.45973104], dtype=float32),
#   'probabilities': array([0.54026896, 0.45973104], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9135716], dtype=float32),
#   'logistic': array([0.12858012], dtype=float32),
#   'probabilities': array([0.87141985, 0.12858012], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5198476], dtype=float32),
#   'logistic': array([0.3728879], dtype=float32),
#   'probabilities': array([0.62711215, 0.37288788], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5633738], dtype=float32),
#   'logistic': array([0.6372328], dtype=float32),
#   'probabilities': array([0.3627672 , 0.63723284], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.00348938], dtype=float32),
#   'logistic': array([0.5008723], dtype=float32),
#   'probabilities': array([0.49912763, 0.5008723 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.56800497], dtype=float32),
#   'logistic': array([0.36169732], dtype=float32),
#   'probabilities': array([0.6383027, 0.3616973], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2258457], dtype=float32),
#   'logistic': array([0.5562226], dtype=float32),
#   'probabilities': array([0.44377735, 0.5562227 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3609815], dtype=float32),
#   'logistic': array([0.20408083], dtype=float32),
#   'probabilities': array([0.7959192 , 0.20408083], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5270131], dtype=float32),
#   'logistic': array([0.17843114], dtype=float32),
#   'probabilities': array([0.8215689 , 0.17843114], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9383771], dtype=float32),
#   'logistic': array([0.12582627], dtype=float32),
#   'probabilities': array([0.87417376, 0.12582625], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0327148], dtype=float32),
#   'logistic': array([0.26255816], dtype=float32),
#   'probabilities': array([0.7374419, 0.2625581], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.06232935], dtype=float32),
#   'logistic': array([0.4844227], dtype=float32),
#   'probabilities': array([0.5155773 , 0.48442274], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.56459033], dtype=float32),
#   'logistic': array([0.637514], dtype=float32),
#   'probabilities': array([0.362486, 0.637514], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1984998], dtype=float32),
#   'logistic': array([0.23174223], dtype=float32),
#   'probabilities': array([0.76825774, 0.23174219], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6437811], dtype=float32),
#   'logistic': array([0.16195124], dtype=float32),
#   'probabilities': array([0.83804876, 0.16195123], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.3323735], dtype=float32),
#   'logistic': array([0.41766325], dtype=float32),
#   'probabilities': array([0.5823368 , 0.41766322], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2334454], dtype=float32),
#   'logistic': array([0.22557896], dtype=float32),
#   'probabilities': array([0.7744211, 0.225579 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7735839], dtype=float32),
#   'logistic': array([0.14509721], dtype=float32),
#   'probabilities': array([0.8549028 , 0.14509721], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4584109], dtype=float32),
#   'logistic': array([0.1887105], dtype=float32),
#   'probabilities': array([0.81128955, 0.18871051], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9066828], dtype=float32),
#   'logistic': array([0.12935394], dtype=float32),
#   'probabilities': array([0.870646  , 0.12935399], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.38881725], dtype=float32),
#   'logistic': array([0.40400207], dtype=float32),
#   'probabilities': array([0.5959979 , 0.40400204], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0602612], dtype=float32),
#   'logistic': array([0.74274045], dtype=float32),
#   'probabilities': array([0.25725952, 0.74274045], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0518062], dtype=float32),
#   'logistic': array([0.74112153], dtype=float32),
#   'probabilities': array([0.2588784, 0.7411216], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.03241539], dtype=float32),
#   'logistic': array([0.50810313], dtype=float32),
#   'probabilities': array([0.49189687, 0.50810313], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.04257941], dtype=float32),
#   'logistic': array([0.48935676], dtype=float32),
#   'probabilities': array([0.51064324, 0.48935676], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.22992826], dtype=float32),
#   'logistic': array([0.5572301], dtype=float32),
#   'probabilities': array([0.44276986, 0.5572302 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.044426], dtype=float32),
#   'logistic': array([0.11461678], dtype=float32),
#   'probabilities': array([0.8853832 , 0.11461682], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.07573235], dtype=float32),
#   'logistic': array([0.51892406], dtype=float32),
#   'probabilities': array([0.48107597, 0.51892406], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0276098], dtype=float32),
#   'logistic': array([0.7364523], dtype=float32),
#   'probabilities': array([0.26354775, 0.7364523 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.41745096], dtype=float32),
#   'logistic': array([0.39712688], dtype=float32),
#   'probabilities': array([0.6028731 , 0.39712682], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0996152], dtype=float32),
#   'logistic': array([0.24981204], dtype=float32),
#   'probabilities': array([0.750188, 0.249812], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.82955515], dtype=float32),
#   'logistic': array([0.30373913], dtype=float32),
#   'probabilities': array([0.69626087, 0.30373913], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.26121318], dtype=float32),
#   'logistic': array([0.5649345], dtype=float32),
#   'probabilities': array([0.43506548, 0.5649345 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2025676], dtype=float32),
#   'logistic': array([0.23101878], dtype=float32),
#   'probabilities': array([0.7689812 , 0.23101877], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.51563513], dtype=float32),
#   'logistic': array([0.6261265], dtype=float32),
#   'probabilities': array([0.37387344, 0.6261265 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.38672632], dtype=float32),
#   'logistic': array([0.4045056], dtype=float32),
#   'probabilities': array([0.5954944, 0.4045056], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.3680293], dtype=float32),
#   'logistic': array([0.4090173], dtype=float32),
#   'probabilities': array([0.5909827 , 0.40901726], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6824551], dtype=float32),
#   'logistic': array([0.15677065], dtype=float32),
#   'probabilities': array([0.8432293 , 0.15677065], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5238402], dtype=float32),
#   'logistic': array([0.17889673], dtype=float32),
#   'probabilities': array([0.8211033 , 0.17889673], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4941435], dtype=float32),
#   'logistic': array([0.18330061], dtype=float32),
#   'probabilities': array([0.8166993 , 0.18330061], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.30118555], dtype=float32),
#   'logistic': array([0.4252677], dtype=float32),
#   'probabilities': array([0.5747323, 0.4252677], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7315965], dtype=float32),
#   'logistic': array([0.15038347], dtype=float32),
#   'probabilities': array([0.8496165 , 0.15038349], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8117869], dtype=float32),
#   'logistic': array([0.69249016], dtype=float32),
#   'probabilities': array([0.30750984, 0.6924901 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4501811], dtype=float32),
#   'logistic': array([0.18997368], dtype=float32),
#   'probabilities': array([0.8100263 , 0.18997368], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.07550675], dtype=float32),
#   'logistic': array([0.48113227], dtype=float32),
#   'probabilities': array([0.51886773, 0.48113227], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.69624], dtype=float32),
#   'logistic': array([0.154957], dtype=float32),
#   'probabilities': array([0.84504294, 0.15495698], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.60496676], dtype=float32),
#   'logistic': array([0.64679176], dtype=float32),
#   'probabilities': array([0.3532082, 0.6467918], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.0212736], dtype=float32),
#   'logistic': array([0.2647794], dtype=float32),
#   'probabilities': array([0.73522055, 0.26477936], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.413325], dtype=float32),
#   'logistic': array([0.19571017], dtype=float32),
#   'probabilities': array([0.8042899 , 0.19571015], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.81143105], dtype=float32),
#   'logistic': array([0.30758566], dtype=float32),
#   'probabilities': array([0.69241434, 0.30758563], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7445998], dtype=float32),
#   'logistic': array([0.3219991], dtype=float32),
#   'probabilities': array([0.67800087, 0.3219991 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.543998], dtype=float32),
#   'logistic': array([0.17595482], dtype=float32),
#   'probabilities': array([0.8240451 , 0.17595482], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.76610744], dtype=float32),
#   'logistic': array([0.6826782], dtype=float32),
#   'probabilities': array([0.31732175, 0.6826782 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3744138], dtype=float32),
#   'logistic': array([0.20190766], dtype=float32),
#   'probabilities': array([0.7980923 , 0.20190763], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5178452], dtype=float32),
#   'logistic': array([0.17977905], dtype=float32),
#   'probabilities': array([0.82022095, 0.17977905], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0329053], dtype=float32),
#   'logistic': array([0.26252124], dtype=float32),
#   'probabilities': array([0.7374788 , 0.26252124], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.33162647], dtype=float32),
#   'logistic': array([0.41784495], dtype=float32),
#   'probabilities': array([0.5821551 , 0.41784495], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2428204], dtype=float32),
#   'logistic': array([0.22394545], dtype=float32),
#   'probabilities': array([0.77605456, 0.22394542], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9828384], dtype=float32),
#   'logistic': array([0.12101658], dtype=float32),
#   'probabilities': array([0.8789834 , 0.12101658], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.5685904], dtype=float32),
#   'logistic': array([0.8275826], dtype=float32),
#   'probabilities': array([0.17241745, 0.8275826 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5562092], dtype=float32),
#   'logistic': array([0.63557494], dtype=float32),
#   'probabilities': array([0.364425  , 0.63557494], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.1032998], dtype=float32),
#   'logistic': array([0.47419798], dtype=float32),
#   'probabilities': array([0.525802  , 0.47419798], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.81822944], dtype=float32),
#   'logistic': array([0.69386035], dtype=float32),
#   'probabilities': array([0.30613962, 0.69386035], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8996079], dtype=float32),
#   'logistic': array([0.13015282], dtype=float32),
#   'probabilities': array([0.8698471 , 0.13015287], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7857549], dtype=float32),
#   'logistic': array([0.14359394], dtype=float32),
#   'probabilities': array([0.856406  , 0.14359395], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.299796], dtype=float32),
#   'logistic': array([0.21419933], dtype=float32),
#   'probabilities': array([0.78580064, 0.21419935], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6715714], dtype=float32),
#   'logistic': array([0.33814508], dtype=float32),
#   'probabilities': array([0.6618549 , 0.33814508], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.593353], dtype=float32),
#   'logistic': array([0.35586593], dtype=float32),
#   'probabilities': array([0.6441341, 0.3558659], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.06273723], dtype=float32),
#   'logistic': array([0.5156792], dtype=float32),
#   'probabilities': array([0.48432085, 0.5156792 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.17215037], dtype=float32),
#   'logistic': array([0.5429316], dtype=float32),
#   'probabilities': array([0.45706835, 0.5429316 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.47317058], dtype=float32),
#   'logistic': array([0.3838661], dtype=float32),
#   'probabilities': array([0.6161339, 0.3838661], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6967515], dtype=float32),
#   'logistic': array([0.33253288], dtype=float32),
#   'probabilities': array([0.6674671 , 0.33253285], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.67076904], dtype=float32),
#   'logistic': array([0.33832467], dtype=float32),
#   'probabilities': array([0.66167533, 0.33832467], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4439775], dtype=float32),
#   'logistic': array([0.19093016], dtype=float32),
#   'probabilities': array([0.8090698 , 0.19093017], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.35787094], dtype=float32),
#   'logistic': array([0.58852494], dtype=float32),
#   'probabilities': array([0.41147506, 0.58852494], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8801391], dtype=float32),
#   'logistic': array([0.13237289], dtype=float32),
#   'probabilities': array([0.86762714, 0.1323729 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1648749], dtype=float32),
#   'logistic': array([0.23778263], dtype=float32),
#   'probabilities': array([0.7622174 , 0.23778263], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.03903031], dtype=float32),
#   'logistic': array([0.5097563], dtype=float32),
#   'probabilities': array([0.49024364, 0.5097563 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.7241676], dtype=float32),
#   'logistic': array([0.32647592], dtype=float32),
#   'probabilities': array([0.6735241 , 0.32647592], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4095623], dtype=float32),
#   'logistic': array([0.19630313], dtype=float32),
#   'probabilities': array([0.8036969 , 0.19630308], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0461005], dtype=float32),
#   'logistic': array([0.2599746], dtype=float32),
#   'probabilities': array([0.7400254 , 0.25997463], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1157284], dtype=float32),
#   'logistic': array([0.2468045], dtype=float32),
#   'probabilities': array([0.7531955, 0.2468045], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8448544], dtype=float32),
#   'logistic': array([0.13647819], dtype=float32),
#   'probabilities': array([0.86352175, 0.13647817], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3517829], dtype=float32),
#   'logistic': array([0.20557904], dtype=float32),
#   'probabilities': array([0.79442096, 0.20557906], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.12489057], dtype=float32),
#   'logistic': array([0.5311821], dtype=float32),
#   'probabilities': array([0.4688179, 0.5311821], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.73051846], dtype=float32),
#   'logistic': array([0.674919], dtype=float32),
#   'probabilities': array([0.325081  , 0.67491907], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.4596746], dtype=float32),
#   'logistic': array([0.612937], dtype=float32),
#   'probabilities': array([0.38706303, 0.612937  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.64516544], dtype=float32),
#   'logistic': array([0.6559202], dtype=float32),
#   'probabilities': array([0.34407985, 0.6559202 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.23705155], dtype=float32),
#   'logistic': array([0.44101304], dtype=float32),
#   'probabilities': array([0.5589869 , 0.44101307], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8920027], dtype=float32),
#   'logistic': array([0.29069674], dtype=float32),
#   'probabilities': array([0.7093033, 0.2906967], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.01283193], dtype=float32),
#   'logistic': array([0.49679205], dtype=float32),
#   'probabilities': array([0.5032079 , 0.49679205], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4548914], dtype=float32),
#   'logistic': array([0.18924993], dtype=float32),
#   'probabilities': array([0.81075007, 0.1892499 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6816192], dtype=float32),
#   'logistic': array([0.15688115], dtype=float32),
#   'probabilities': array([0.8431188 , 0.15688118], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4828246], dtype=float32),
#   'logistic': array([0.1850012], dtype=float32),
#   'probabilities': array([0.81499887, 0.18500116], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.08069372], dtype=float32),
#   'logistic': array([0.4798375], dtype=float32),
#   'probabilities': array([0.5201625 , 0.47983754], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.75822], dtype=float32),
#   'logistic': array([0.05962408], dtype=float32),
#   'probabilities': array([0.94037586, 0.05962409], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0050654], dtype=float32),
#   'logistic': array([0.2679467], dtype=float32),
#   'probabilities': array([0.73205334, 0.26794666], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.546625], dtype=float32),
#   'logistic': array([0.17557426], dtype=float32),
#   'probabilities': array([0.82442576, 0.17557426], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0107561], dtype=float32),
#   'logistic': array([0.2668319], dtype=float32),
#   'probabilities': array([0.73316807, 0.2668319 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.099593], dtype=float32),
#   'logistic': array([0.24981615], dtype=float32),
#   'probabilities': array([0.7501838 , 0.24981613], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9735598], dtype=float32),
#   'logistic': array([0.27417153], dtype=float32),
#   'probabilities': array([0.72582847, 0.27417153], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0732486], dtype=float32),
#   'logistic': array([0.7452142], dtype=float32),
#   'probabilities': array([0.25478578, 0.7452142 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6191384], dtype=float32),
#   'logistic': array([0.16532373], dtype=float32),
#   'probabilities': array([0.8346762 , 0.16532372], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0276484], dtype=float32),
#   'logistic': array([0.11633039], dtype=float32),
#   'probabilities': array([0.88366956, 0.11633044], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.12545943], dtype=float32),
#   'logistic': array([0.5313238], dtype=float32),
#   'probabilities': array([0.4686762, 0.5313238], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.08989191], dtype=float32),
#   'logistic': array([0.47754213], dtype=float32),
#   'probabilities': array([0.52245784, 0.4775421 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.507967], dtype=float32),
#   'logistic': array([0.8187597], dtype=float32),
#   'probabilities': array([0.18124029, 0.81875974], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.51654065], dtype=float32),
#   'logistic': array([0.6263385], dtype=float32),
#   'probabilities': array([0.3736615, 0.6263385], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.00002], dtype=float32),
#   'logistic': array([0.11920082], dtype=float32),
#   'probabilities': array([0.8807992 , 0.11920082], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.45931315], dtype=float32),
#   'logistic': array([0.6128512], dtype=float32),
#   'probabilities': array([0.38714877, 0.6128512 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)}]

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmplaxfhgp8
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmplaxfhgp8', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x13bd09a90>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-391751ec2827> in <module>
# ----> 1 dnn_model.train(input_fn=input_func, steps=1000)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1152       worker_hooks.extend(input_hooks)
#    1153       estimator_spec = self._call_model_fn(
# -> 1154           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#    1155       global_step_tensor = training_util.get_global_step(g)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1110
#    1111     logging.info('Calling model_fn.')
# -> 1112     model_fn_results = self._model_fn(features=features, **kwargs)
#    1113     logging.info('Done calling model_fn.')
#    1114
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     520           input_layer_partitioner=input_layer_partitioner,
#     521           config=config,
# --> 522           batch_norm=batch_norm)
#     523
#     524     super(DNNClassifier, self).__init__(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     285         input_layer_partitioner=input_layer_partitioner,
#     286         batch_norm=batch_norm)
# --> 287     logits = logit_fn(features=features, mode=mode)
#     288
#     289     if use_tpu:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#     100         input_layer_partitioner,
#     101         batch_norm,
# --> 102         name='dnn')
#     103     return dnn_model(features, mode)
#     104
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     127     if feature_column_lib.is_feature_column_v2(feature_columns):
#     128       self._input_layer = feature_column_lib.DenseFeatures(
# --> 129           feature_columns=feature_columns, name='input_layer')
#     130     else:
#     131       self._input_layer = feature_column.InputLayer(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#     364             'Items of feature_columns must be a DenseColumn. '
#     365             'You can wrap a categorical column with an '
# --> 366             'embedding_column or indicator_column. Given: {}'.format(column))
#     367
#     368   @property
#
# ValueError: Items of feature_columns must be a DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
#wrap a categorical column with an embedding_colum

# %%
embedded_group_col = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, embedded_group_col, age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train, y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmpoz49a2c5
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmpoz49a2c5', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x13bf5cdd8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2997: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmpoz49a2c5/model.ckpt.
# INFO:tensorflow:loss = 6.843259, step = 1
# INFO:tensorflow:global_step/sec: 306.176
# INFO:tensorflow:loss = 5.229092, step = 101 (0.331 sec)
# INFO:tensorflow:global_step/sec: 455.826
# INFO:tensorflow:loss = 5.2403975, step = 201 (0.216 sec)
# INFO:tensorflow:global_step/sec: 496.593
# INFO:tensorflow:loss = 6.354706, step = 301 (0.199 sec)
# INFO:tensorflow:global_step/sec: 537.412
# INFO:tensorflow:loss = 3.0667071, step = 401 (0.186 sec)
# INFO:tensorflow:global_step/sec: 538.549
# INFO:tensorflow:loss = 5.345855, step = 501 (0.186 sec)
# INFO:tensorflow:global_step/sec: 489.436
# INFO:tensorflow:loss = 5.7672668, step = 601 (0.205 sec)
# INFO:tensorflow:global_step/sec: 235.085
# INFO:tensorflow:loss = 4.7039475, step = 701 (0.425 sec)
# INFO:tensorflow:global_step/sec: 532.552
# INFO:tensorflow:loss = 6.4368806, step = 801 (0.189 sec)
# INFO:tensorflow:global_step/sec: 453.275
# INFO:tensorflow:loss = 4.2144027, step = 901 (0.224 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmpoz49a2c5/model.ckpt.
# INFO:tensorflow:Loss for final step: 8.067368.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-22T09:00:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmpoz49a2c5/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-06-22-09:00:35
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7619048, accuracy_baseline = 0.64935064, auc = 0.83436215, auc_precision_recall = 0.70742506, average_loss = 0.48481315, global_step = 1000, label/mean = 0.35064936, loss = 4.6663265, precision = 0.6354167, prediction/mean = 0.40427986, recall = 0.75308645
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/2d/29b083p92c546v8fprd0v3mw0000gn/T/tmpoz49a2c5/model.ckpt-1000
# {'accuracy': 0.7619048,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.83436215,
#  'auc_precision_recall': 0.70742506,
#  'average_loss': 0.48481315,
#  'label/mean': 0.35064936,
#  'loss': 4.6663265,
#  'precision': 0.6354167,
#  'prediction/mean': 0.40427986,
#  'recall': 0.75308645,
#  'global_step': 1000}
